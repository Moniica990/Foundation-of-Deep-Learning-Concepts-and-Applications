# %% [markdown]
# <a href="https://colab.research.google.com/github/Moniica990/Foundation-of-Deep-Learning-Concepts-and-Applications/blob/main/simple_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x=np.array([1.0,2.0])
y=1#target
w=np.array([0.2,-0.5])
b=0.1
eta=0.1 #learning rate

# %%
#run for 4 epochs
for epoch in range(1,4):
  print(f"\nEpoch{epoch}:")
  net_input=np.dot(w,x)+b
  y_pred=1 if net_input>0 else 0
  error=y-y_pred


  print(f"net inout={net_input:.2f}")
  print(f"predicted output={y_pred}")
  print(f"error={error}")

  #update rule
  w=w+eta*error*x
  b=b+eta*error
  print(f"updated weights={w}")
  print(f"updated bias={b:.2f}")
# Out:
# Epoch1:
# net inout=-0.70
# predicted output=0
# error=1
# updated weights=[ 0.3 -0.3]
# updated bias=0.20
#
# Epoch2:
# net inout=-0.10
# predicted output=0
# error=1
# updated weights=[ 0.4 -0.1]
# updated bias=0.30
#
# Epoch3:
# net inout=0.50
# predicted output=1
# error=0
# updated weights=[ 0.4 -0.1]
# updated bias=0.30
